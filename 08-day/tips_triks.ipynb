# %% [markdown]
# written by:Muhammad Javed\
# Date: 2024-11-06\
# Email: meherjaved440@gmail.com

# %% [markdown]
# # 1- How to find version

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit                : 0691c5cf90477d3503834d983f69350f250a6ff7
# python                : 3.13.0
# python-bits           : 64
# OS                    : Windows
# OS-release            : 10
# Version               : 10.0.19045
# machine               : AMD64
# processor             : Intel64 Family 6 Model 165 Stepping 2, GenuineIntel
# byteorder             : little
# LC_ALL                : None
# LANG                  : None
# LOCALE                : English_United States.1252
#
# pandas                : 2.2.3
# numpy                 : 2.1.3
# pytz                  : 2024.2
# dateutil              : 2.9.0.post0
# pip                   : 24.2
# Cython                : None
# sphinx                : None
# IPython               : 8.29.0
# adbc-driver-postgresql: None
# adbc-driver-sqlite    : None
# bs4                   : None
# blosc                 : None
# bottleneck            : None
# dataframe-api-compat  : None
# ...

# %% [markdown]
# # 02- Make a dataframe

# %%
df=pd.DataFrame({'A':[1,2,3,4,5,6,7,8,9,0], 'B':[0,9,8,7,6,5,4,3,2,1]})
df
# Out:
#    A  B
# 0  1  0
# 1  2  9
# 2  3  8
# 3  4  7
# 4  5  6
# 5  6  5
# 6  7  4
# 7  8  3
# 8  9  2
# 9  0  1

# %%
df.head(3)
# Out:
#    A  B
# 0  1  0
# 1  2  9
# 2  3  8

# %%
df.tail(4)
# Out:
#    A  B
# 6  7  4
# 7  8  3
# 8  9  2
# 9  0  1

# %%
df.shape
# Out:
# (10, 2)

# %%
df.info
# Out:
# <bound method DataFrame.info of    A  B
# 0  1  0
# 1  2  9
# 2  3  8
# 3  4  7
# 4  5  6
# 5  6  5
# 6  7  4
# 7  8  3
# 8  9  2
# 9  0  1>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       10 non-null     int64
#  1   B       10 non-null     int64
# dtypes: int64(2)
# memory usage: 292.0 bytes

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.sort_index()
# Out:
#    A  B
# 0  1  0
# 1  2  9
# 2  3  8
# 3  4  7
# 4  5  6
# 5  6  5
# 6  7  4
# 7  8  3
# 8  9  2
# 9  0  1

# %%
df.describe()
# Out:
#               A         B
# count  10.00000  10.00000
# mean    4.50000   4.50000
# std     3.02765   3.02765
# min     0.00000   0.00000
# 25%     2.25000   2.25000
# 50%     4.50000   4.50000
# 75%     6.75000   6.75000
# max     9.00000   9.00000

# %%
import numpy as np

# %%
arr=np.array([[1,2,3,4],[3,4,5,6],[7,8,9,0]])
arr
df=pd.DataFrame(arr)
df
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  3  4  5  6
# 2  7  8  9  0

# %%
# another way to create dataset

rd=pd.DataFrame(np.random.rand(9,9))
rd
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.566107  0.882564  0.331417  0.635823  0.169520  0.478784  0.584316
# 1  0.431771  0.281222  0.908789  0.781814  0.197408  0.681650  0.055342
# 2  0.136951  0.906284  0.639709  0.630104  0.891569  0.054168  0.506745
# 3  0.155801  0.469645  0.714805  0.240769  0.313486  0.182538  0.114649
# 4  0.704470  0.557917  0.595901  0.510991  0.187243  0.385198  0.563137
# 5  0.683397  0.981304  0.930707  0.152843  0.017773  0.748581  0.188610
# 6  0.940143  0.196962  0.477837  0.086931  0.426146  0.064526  0.410297
# 7  0.130595  0.429726  0.494412  0.074621  0.951633  0.440756  0.256996
# 8  0.269735  0.109322  0.592230  0.436235  0.256420  0.809101  0.351841
#
#           7         8
# 0  0.532416  0.947568
# 1  0.350891  0.193037
# 2  0.965610  0.479253
# 3  0.462405  0.318451
# 4  0.147718  0.011528
# 5  0.592072  0.338964
# 6  0.750103  0.332166
# 7  0.564464  0.151407
# 8  0.206379  0.641108

# %%
rn=pd.DataFrame(np.random.rand(9,9), columns=list('ABCDEFGHI'))
rn
# Out:
#           A         B         C         D         E         F         G  \
# 0  0.132968  0.202435  0.991490  0.822728  0.745399  0.008364  0.788282
# 1  0.385080  0.842762  0.991324  0.989699  0.096508  0.120912  0.885621
# 2  0.490312  0.479819  0.815462  0.986019  0.213612  0.470889  0.821871
# 3  0.408432  0.733447  0.637790  0.391245  0.041964  0.304270  0.289703
# 4  0.357156  0.863086  0.054854  0.811356  0.779569  0.120917  0.588593
# 5  0.426432  0.860428  0.698419  0.899827  0.963086  0.547663  0.793377
# 6  0.720137  0.856276  0.392911  0.644946  0.732038  0.554531  0.597171
# 7  0.880462  0.892926  0.252783  0.560404  0.372669  0.063966  0.462733
# 8  0.952747  0.800413  0.684467  0.294169  0.487345  0.470390  0.716126
#
#           H         I
# 0  0.128254  0.361958
# 1  0.258865  0.326626
# 2  0.112595  0.248682
# 3  0.623252  0.518120
# 4  0.712690  0.309340
# 5  0.326440  0.439746
# 6  0.862970  0.664682
# 7  0.845892  0.846290
# 8  0.698452  0.719371

# %% [markdown]
# # 3- How to rename columns

# %%
df
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  3  4  5  6
# 2  7  8  9  0

# %%
rn.rename(columns={'A':'ALI','B':'BALI','C':'CALI','D':'DALI','E':'ELILI','F':'FALI','G':'GALI','H':'HALI','I':'ILLI'}, inplace=True)
rn
# Out:
#         ALI      BALI      CALI      DALI     ELILI      FALI      GALI  \
# 0  0.132968  0.202435  0.991490  0.822728  0.745399  0.008364  0.788282
# 1  0.385080  0.842762  0.991324  0.989699  0.096508  0.120912  0.885621
# 2  0.490312  0.479819  0.815462  0.986019  0.213612  0.470889  0.821871
# 3  0.408432  0.733447  0.637790  0.391245  0.041964  0.304270  0.289703
# 4  0.357156  0.863086  0.054854  0.811356  0.779569  0.120917  0.588593
# 5  0.426432  0.860428  0.698419  0.899827  0.963086  0.547663  0.793377
# 6  0.720137  0.856276  0.392911  0.644946  0.732038  0.554531  0.597171
# 7  0.880462  0.892926  0.252783  0.560404  0.372669  0.063966  0.462733
# 8  0.952747  0.800413  0.684467  0.294169  0.487345  0.470390  0.716126
#
#        HALI      ILLI
# 0  0.128254  0.361958
# 1  0.258865  0.326626
# 2  0.112595  0.248682
# 3  0.623252  0.518120
# 4  0.712690  0.309340
# 5  0.326440  0.439746
# 6  0.862970  0.664682
# 7  0.845892  0.846290
# 8  0.698452  0.719371

# %%
rd=pd.DataFrame(np.random.rand(6,2),columns=list('ab'))
rd
# Out:
#           a         b
# 0  0.386311  0.185067
# 1  0.450995  0.633741
# 2  0.811607  0.959591
# 3  0.444259  0.602022
# 4  0.116094  0.335476
# 5  0.933106  0.099872

# %%
# To rename columns
rd.rename(columns={'a':'A','b':'B'})
# Out:
#           A         B
# 0  0.386311  0.185067
# 1  0.450995  0.633741
# 2  0.811607  0.959591
# 3  0.444259  0.602022
# 4  0.116094  0.335476
# 5  0.933106  0.099872

# %%
# Another way to rename columns
rd.columns=['AA','BB']
rd
# Out:
#          AA        BB
# 0  0.386311  0.185067
# 1  0.450995  0.633741
# 2  0.811607  0.959591
# 3  0.444259  0.602022
# 4  0.116094  0.335476
# 5  0.933106  0.099872

# %%
rd.columns=['javed','ali']
rd
# Out:
#       javed       ali
# 0  0.386311  0.185067
# 1  0.450995  0.633741
# 2  0.811607  0.959591
# 3  0.444259  0.602022
# 4  0.116094  0.335476
# 5  0.933106  0.099872

# %%
# It is used
rd.columns=rd.columns.str.replace('a','z')
rd
# Out:
#       jzved       zli
# 0  0.386311  0.185067
# 1  0.450995  0.633741
# 2  0.811607  0.959591
# 3  0.444259  0.602022
# 4  0.116094  0.335476
# 5  0.933106  0.099872

# %%
# Adding prefix to columns
jd=rd.add_prefix('*')
jd
# Out:
#      *jzved      *zli
# 0  0.386311  0.185067
# 1  0.450995  0.633741
# 2  0.811607  0.959591
# 3  0.444259  0.602022
# 4  0.116094  0.335476
# 5  0.933106  0.099872

# %%
# Adding suffix to columns
jc=jd.add_suffix('$')
jc
# Out:
#     *jzved$     *zli$
# 0  0.386311  0.185067
# 1  0.450995  0.633741
# 2  0.811607  0.959591
# 3  0.444259  0.602022
# 4  0.116094  0.335476
# 5  0.933106  0.099872

# %% [markdown]
# # 4- Using template data

# %%
import pandas as pd 
import numpy as np
import seaborn as  sns

# %%
kashti= sns.load_dataset('titanic')
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tips= sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
phool=sns.load_dataset('iris')
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
phool.head(4)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa

# %%
phool.tail(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
phool.shape
# Out:
# (150, 5)

# %%
# To see summary of phool
phool.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# To check columns name
phool.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# Saving dataset
phool.to_csv('phool_save.csv')

# %%
phool.to_excel('phool.xlsx')

# %% [markdown]
# # 5- using your own data

# %%
import pandas as pd
df= pd.read_csv('phool_save.csv')
df
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 0             0           5.1          3.5           1.4          0.2
# 1             1           4.9          3.0           1.4          0.2
# 2             2           4.7          3.2           1.3          0.2
# 3             3           4.6          3.1           1.5          0.2
# 4             4           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         145           6.7          3.0           5.2          2.3
# 146         146           6.3          2.5           5.0          1.9
# 147         147           6.5          3.0           5.2          2.0
# 148         148           6.2          3.4           5.4          2.3
# 149         149           5.9          3.0           5.1          1.8
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
ds=pd.read_excel('phool.xlsx')
ds
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 0             0           5.1          3.5           1.4          0.2
# 1             1           4.9          3.0           1.4          0.2
# 2             2           4.7          3.2           1.3          0.2
# 3             3           4.6          3.1           1.5          0.2
# 4             4           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         145           6.7          3.0           5.2          2.3
# 146         146           6.3          2.5           5.0          1.9
# 147         147           6.5          3.0           5.2          2.0
# 148         148           6.2          3.4           5.4          2.3
# 149         149           5.9          3.0           5.1          1.8
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %% [markdown]
# # 6-Reverse Row order

# %%
import seaborn as sns
import pandas as pd
df =sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.head(-7)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.loc[::-1].head()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 890         0       3    male  32.0      0      0   7.75        Q   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 887         1       1  female  19.0      0      0  30.00        S   First
# 886         0       2    male  27.0      0      0  13.00        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 890    man        True  NaN   Queenstown    no   True
# 889    man        True    C    Cherbourg   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 887  woman       False    B  Southampton   yes   True
# 886    man        True  NaN  Southampton    no   True

# %%
# To reset index
df.loc[::-1].reset_index(drop=True).head()
# Out:
#    survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 0         0       3    male  32.0      0      0   7.75        Q   Third
# 1         1       1    male  26.0      0      0  30.00        C   First
# 2         0       3  female   NaN      1      2  23.45        S   Third
# 3         1       1  female  19.0      0      0  30.00        S   First
# 4         0       2    male  27.0      0      0  13.00        S  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN   Queenstown    no   True
# 1    man        True    C    Cherbourg   yes   True
# 2  woman       False  NaN  Southampton    no  False
# 3  woman       False    B  Southampton   yes   True
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # 7- Reverse column order

# %%
df.loc[:,::-1].head()
# Out:
#    alone alive  embark_town deck  adult_male    who  class embarked     fare  \
# 0  False    no  Southampton  NaN        True    man  Third        S   7.2500
# 1  False   yes    Cherbourg    C       False  woman  First        C  71.2833
# 2   True   yes  Southampton  NaN       False  woman  Third        S   7.9250
# 3  False   yes  Southampton    C       False  woman  First        S  53.1000
# 4   True    no  Southampton  NaN        True    man  Third        S   8.0500
#
#    parch  sibsp   age     sex  pclass  survived
# 0      0      1  22.0    male       3         0
# 1      0      1  38.0  female       1         1
# 2      0      0  26.0  female       3         1
# 3      0      1  35.0  female       1         1
# 4      0      0  35.0    male       3         0

# %% [markdown]
# # 8- Select a column by data type

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %% [markdown]
# # Only select those have numeric type

# %%
df.select_dtypes(include=['number']).head()
# Out:
#    survived  pclass   age  sibsp  parch     fare
# 0         0       3  22.0      1      0   7.2500
# 1         1       1  38.0      1      0  71.2833
# 2         1       3  26.0      0      0   7.9250
# 3         1       1  35.0      1      0  53.1000
# 4         0       3  35.0      0      0   8.0500

# %%
df.select_dtypes(include=['bool']).head()
# Out:
#    adult_male  alone
# 0        True  False
# 1       False  False
# 2       False   True
# 3       False  False
# 4        True   True

# %%
df.select_dtypes(include=['category']).head()
# Out:
#    class deck
# 0  Third  NaN
# 1  First    C
# 2  Third  NaN
# 3  First    C
# 4  Third  NaN

# %%
df.select_dtypes(include=['object']).head()
# Out:
#       sex embarked    who  embark_town alive
# 0    male        S    man  Southampton    no
# 1  female        C  woman    Cherbourg   yes
# 2  female        S  woman  Southampton   yes
# 3  female        S  woman  Southampton   yes
# 4    male        S    man  Southampton    no

# %%
df.select_dtypes(exclude=['number','bool','category']).head()
# Out:
#       sex embarked    who  embark_town alive
# 0    male        S    man  Southampton    no
# 1  female        C  woman    Cherbourg   yes
# 2  female        S  woman  Southampton   yes
# 3  female        S  woman  Southampton   yes
# 4    male        S    man  Southampton    no

# %% [markdown]
# # 9- Convert string to numbermm

# %%
df=pd.DataFrame({'A':[1,2,3,4,5], 'B':[6,7,8,9,0]})
df
# Out:
#    A  B
# 0  1  6
# 1  2  7
# 2  3  8
# 3  4  9
# 4  5  0

# %%
df.dtypes
# Out:
# A    int64
# B    int64
# dtype: object

# %%
df=pd.DataFrame({'A':['1','2','3','4'], 'B':['5','6','7','8']})
df
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
df.dtypes
# Out:
# A    object
# B    object
# dtype: object

# %%
df.astype({'A':'int64', 'B':'int64'}).dtypes
# Out:
# A    int64
# B    int64
# dtype: object

# %%
df
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
# It tells pandas to handle any errors bysetting invalid values to NaN(Not a Number), rather than raising an error.
pd.to_numeric(df['A'], errors='coerce')
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: A, dtype: int64

# %%
df.astype({'A':'float', 'B':'int64'}).dtypes
# Out:
# A    float64
# B      int64
# dtype: object

# %%
pd.to_numeric(df['A'], errors='coerce')
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: A, dtype: int64

# %% [markdown]
# # 10- Reduce dataframe size

# %%
df=sns.load_dataset('titanic')
df.shape
# Out:
# (891, 15)

# %%
df.sample(frac=0.1).shape
# Out:
# (89, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# # 11- Copy data from clip board

# %%
# dataset
import seaborn as sns
import pandas as pd
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.to_excel('kashti.xlsx')

# %% [markdown]
# # Read clipboard in python

# %%
# df = pd.read_clipboard()
# df
# df.to_excel('javed.xlsx')

# %%
# df = pd.read_clipboard()
# df

# %% [markdown]
# # 12- Split dataframe into two subsets

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
len(df)
# Out:
# 891

# %%
df.shape
# Out:
# (891, 15)

# %%
from random import random
kashti_1 = df.sample(frac=0.50, random_state=1)
kashti_1.shape
# Out:
# (446, 15)

# %%
kashti_2 = df.drop(kashti_1.index)
kashti_2.shape
# Out:
# (445, 15)

# %%
kashti_2.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 7   child       False  NaN  Southampton    no  False
# 10  child       False    G  Southampton   yes  False
# 15  woman       False  NaN  Southampton   yes   True
# 18  woman       False  NaN  Southampton    no  False

# %%
kashti_1.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 862         1       1  female  48.0      0      0  25.9292        S   First
# 223         0       3    male   NaN      0      0   7.8958        S   Third
# 84          1       2  female  17.0      0      0  10.5000        S  Second
# 680         0       3  female   NaN      0      0   8.1375        Q   Third
# 535         1       2  female   7.0      0      2  26.2500        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 862  woman       False    D  Southampton   yes   True
# 223    man        True  NaN  Southampton    no   True
# 84   woman       False  NaN  Southampton   yes   True
# 680  woman       False  NaN   Queenstown    no   True
# 535  child       False  NaN  Southampton   yes  False

# %%
len(kashti_1)+len(kashti_2)
# Out:
# 891

# %% [markdown]
# # 13- Join two datasets

# %%
# df1 = kashti_1.insert(kashti_2)
# df1.shape

# %% [markdown]
# # 14- Filtering a datasets

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df[(df.sex=="female")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[(df.sex=='male')]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.embark_town.unique()
df[(df.embark_town=='Southampton')].shape
# Out:
# (644, 15)

# %%
df.embark_town.unique()
df[((df.embark_town=='Southampton')|(df.embark_town=='Queenstown'))&(df.sex=='male')]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 881         0       3  male  33.0      0      0   7.8958        S   Third
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[df.embark_town.isin(['Queenstown'])].head(3)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 5          0       3    male   NaN      0      0   8.4583        Q  Third
# 16         0       3    male   2.0      4      1  29.1250        Q  Third
# 22         1       3  female  15.0      0      0   8.0292        Q  Third
#
#       who  adult_male deck embark_town alive  alone
# 5     man        True  NaN  Queenstown    no   True
# 16  child       False  NaN  Queenstown    no  False
# 22  child       False  NaN  Queenstown   yes   True

# %%
ad=df[df.age<1]
ad.shape
# Out:
# (7, 15)

# %% [markdown]
# # 15- Filtering by large categories

# %%
df.embark_town.value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
df.sex.value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.age.value_counts()
# Out:
# age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df.age.value_counts().nlargest(4).index
# Out:
# Index([24.0, 22.0, 18.0, 28.0], dtype='float64', name='age')

# %% [markdown]
# # 16- Splitting a string into multiple columns

# %%
import pandas as pd
df = pd.DataFrame({'Name':['Muhammad Javed','Muhammad Ali','Muhammad Amjad'], 'Location':['Lahore,Pakistan','Pindi,Pakistan','Karachi,Pakistan'],  'Age':[25,30,35]})
df
# Out:
#              Name          Location  Age
# 0  Muhammad Javed   Lahore,Pakistan   25
# 1    Muhammad Ali    Pindi,Pakistan   30
# 2  Muhammad Amjad  Karachi,Pakistan   35

# %%
df.Name.str.split(' ').head()
# Out:
# 0    [Muhammad, Javed]
# 1      [Muhammad, Ali]
# 2    [Muhammad, Amjad]
# Name: Name, dtype: object

# %%
#  To expand in column
df.Name.str.split(' ',expand=True)
# Out:
#           0      1
# 0  Muhammad  Javed
# 1  Muhammad    Ali
# 2  Muhammad  Amjad

# %%
df[["First_Name","Second_Name"]] = df.Name.str.split(' ', expand=True)
df
# Out:
#              Name          Location  Age First_Name Second_Name
# 0  Muhammad Javed   Lahore,Pakistan   25   Muhammad       Javed
# 1    Muhammad Ali    Pindi,Pakistan   30   Muhammad         Ali
# 2  Muhammad Amjad  Karachi,Pakistan   35   Muhammad       Amjad

# %%
# df[["City_Name","Country_Name"]] = df.Location.str.split(', ', expand=True)
# df

# %%
df = df[['First_Name','Second_Name','Age','Location']]
df
# Out:
#   First_Name Second_Name  Age          Location
# 0   Muhammad       Javed   25   Lahore,Pakistan
# 1   Muhammad         Ali   30    Pindi,Pakistan
# 2   Muhammad       Amjad   35  Karachi,Pakistan

# %% [markdown]
# # 17- Aggregate by multiple groups

# %%
import pandas as pd
import seaborn as sns
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.groupby('who').count()
# Out:
#        survived  pclass  sex  age  sibsp  parch  fare  embarked  class  \
# who
# child        83      83   83   83     83     83    83        83     83
# man         537     537  537  413    537    537   537       537    537
# woman       271     271  271  218    271    271   271       269    271
#
#        adult_male  deck  embark_town  alive  alone
# who
# child          83    13           83     83     83
# man           537    99          537    537    537
# woman         271    91          269    271    271

# %%
len(df.groupby('pclass'))
# Out:
# 3

# %%
len(df.groupby('sex'))
# Out:
# 2

# %%
len(df.groupby('who'))
# Out:
# 3

# %%
df.groupby(['pclass','sex','who']).count()
# Out:
#                      survived  age  sibsp  parch  fare  embarked  class  \
# pclass sex    who
# 1      female child         3    3      3      3     3         3      3
#               woman        91   82     91     91    91        89     91
#        male   child         3    3      3      3     3         3      3
#               man         119   98    119    119   119       119    119
# 2      female child        10   10     10     10    10        10     10
#               woman        66   64     66     66    66        66     66
#        male   child         9    9      9      9     9         9      9
#               man          99   90     99     99    99        99     99
# 3      female child        30   30     30     30    30        30     30
#               woman       114   72    114    114   114       114    114
#        male   child        28   28     28     28    28        28     28
#               man         319  225    319    319   319       319    319
#
# ...

# %% [markdown]
# # 18- Select specific rows or column

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# To select columns
df[['who','sex','age','fare','class','alive','alone']]
# Out:
#        who     sex   age     fare   class alive  alone
# 0      man    male  22.0   7.2500   Third    no  False
# 1    woman  female  38.0  71.2833   First   yes  False
# 2    woman  female  26.0   7.9250   Third   yes   True
# 3    woman  female  35.0  53.1000   First   yes  False
# 4      man    male  35.0   8.0500   Third    no   True
# ..     ...     ...   ...      ...     ...   ...    ...
# 886    man    male  27.0  13.0000  Second    no   True
# 887  woman  female  19.0  30.0000   First   yes   True
# 888  woman  female   NaN  23.4500   Third    no  False
# 889    man    male  26.0  30.0000   First   yes   True
# 890    man    male  32.0   7.7500   Third    no   True
#
# [891 rows x 7 columns]

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# To select rows
df.describe().loc[['count','std','25%','max']]
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe().loc['min':'max']
# Out:
#      survived  pclass     age  sibsp  parch      fare
# min       0.0     1.0   0.420    0.0    0.0    0.0000
# 25%       0.0     2.0  20.125    0.0    0.0    7.9104
# 50%       0.0     3.0  28.000    0.0    0.0   14.4542
# 75%       1.0     3.0  38.000    1.0    0.0   31.0000
# max       1.0     3.0  80.000    8.0    6.0  512.3292

# %%
# To select rows and columns
df.describe().loc['min':'max',['survived','age','fare']]
# Out:
#      survived     age      fare
# min       0.0   0.420    0.0000
# 25%       0.0  20.125    7.9104
# 50%       0.0  28.000   14.4542
# 75%       1.0  38.000   31.0000
# max       1.0  80.000  512.3292

# %%
df.describe().loc['min':'max', 'survived':'age']
# Out:
#      survived  pclass     age
# min       0.0     1.0   0.420
# 25%       0.0     2.0  20.125
# 50%       0.0     3.0  28.000
# 75%       1.0     3.0  38.000
# max       1.0     3.0  80.000

# %% [markdown]
# # 19- Reshape multi index series

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.survived.mean()
# Out:
# np.float64(0.3838383838383838)

# %%
df.groupby('sex').survived.mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
# df.groupby(['sex','class']).survived.mean()    or
df.groupby(['sex','class']).survived.mean().unstack()
# Out:
# C:\Users\TECH ZONE\AppData\Local\Temp\ipykernel_12728\3982741587.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['sex','class']).survived.mean().unstack()
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# # 20- continuous to catogirical data conversion

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
# Creating bins
pd.cut(df.age, bins = [0, 18, 25, 50,100], labels=['child','young_adult','adult','old']).head()
# Out:
# 0    young_adult
# 1          adult
# 2          adult
# 3          adult
# 4          adult
# Name: age, dtype: category
# Categories (4, object): ['child' < 'young_adult' < 'adult' < 'old']

# %%
pd.cut(df.age, bins = [0, 18, 25, 50,100], labels=['child','young_adult','adult','old']).head()
df['new_age'] = pd.cut(df.age, bins = [0, 18, 25, 50,100], labels=['child','young_adult','adult','old']).head()
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age
# 0    man        True  NaN  Southampton    no  False  young_adult
# 1  woman       False    C    Cherbourg   yes  False        adult
# 2  woman       False  NaN  Southampton   yes   True        adult
# 3  woman       False    C  Southampton   yes  False        adult
# 4    man        True  NaN  Southampton    no   True        adult

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age
# 0    man        True  NaN  Southampton    no  False  young_adult
# 1  woman       False    C    Cherbourg   yes  False        adult
# 2  woman       False  NaN  Southampton   yes   True        adult
# 3  woman       False    C  Southampton   yes  False        adult
# 4    man        True  NaN  Southampton    no   True        adult

# %% [markdown]
# # 21- Convert one set of values into another one

# %%
df.sex.head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: sex, dtype: object

# %%
df.sex.map({'male':0, 'female':1})
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    1
# 889    0
# 890    0
# Name: sex, Length: 891, dtype: int64

# %%
df['sex_num'] = df.sex.map({'male':0, 'female':1})
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age  sex_num
# 0    man        True  NaN  Southampton    no  False  young_adult        0
# 1  woman       False    C    Cherbourg   yes  False        adult        1
# 2  woman       False  NaN  Southampton   yes   True        adult        1
# 3  woman       False    C  Southampton   yes  False        adult        1
# 4    man        True  NaN  Southampton    no   True        adult        0

# %%
df.embarked.count()
# Out:
# np.int64(889)

# %%
df.embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['embarked_num'] = df.embarked.factorize()[0]
df.head(9)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
# 7         0       3    male   2.0      3      1  21.0750        S  Third
# 8         1       3  female  27.0      0      2  11.1333        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age  sex_num  \
# 0    man        True  NaN  Southampton    no  False  young_adult        0
# 1  woman       False    C    Cherbourg   yes  False        adult        1
# ...

# %% [markdown]
# # 22- Transpose a wide dataframe

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.rand(200,25), columns=list('ABCDEFGHIJKLMNOPQRSTUVWXY'))
df.head(10)
# Out:
#           A         B         C         D         E         F         G  \
# 0  0.505476  0.969702  0.467354  0.535167  0.517732  0.461393  0.938293
# 1  0.946785  0.000086  0.647640  0.924053  0.279678  0.857037  0.191926
# 2  0.393949  0.591728  0.312626  0.595026  0.917038  0.042271  0.158039
# 3  0.945120  0.209484  0.937293  0.846176  0.330113  0.638996  0.718710
# 4  0.003826  0.254079  0.752864  0.614518  0.263249  0.652500  0.655609
# 5  0.403427  0.767554  0.823377  0.417885  0.379780  0.591384  0.621286
# 6  0.592518  0.509782  0.259649  0.519054  0.438651  0.974793  0.324039
# 7  0.817963  0.550898  0.327941  0.501334  0.104120  0.542488  0.867826
# 8  0.671359  0.833871  0.630279  0.225358  0.160191  0.504284  0.979761
# 9  0.931006  0.235475  0.388731  0.546937  0.328333  0.254415  0.146094
#
#           H         I         J  ...         P         Q         R         S  \
# 0  0.684251  0.783739  0.603751  ...  0.092890  0.626298  0.316214  0.624462
# ...

# %%
df.head(10).T
# Out:
#           0         1         2         3         4         5         6  \
# A  0.505476  0.946785  0.393949  0.945120  0.003826  0.403427  0.592518
# B  0.969702  0.000086  0.591728  0.209484  0.254079  0.767554  0.509782
# C  0.467354  0.647640  0.312626  0.937293  0.752864  0.823377  0.259649
# D  0.535167  0.924053  0.595026  0.846176  0.614518  0.417885  0.519054
# E  0.517732  0.279678  0.917038  0.330113  0.263249  0.379780  0.438651
# F  0.461393  0.857037  0.042271  0.638996  0.652500  0.591384  0.974793
# G  0.938293  0.191926  0.158039  0.718710  0.655609  0.621286  0.324039
# H  0.684251  0.343169  0.829446  0.660501  0.060842  0.727325  0.099047
# I  0.783739  0.756172  0.276371  0.521178  0.716997  0.326978  0.357621
# J  0.603751  0.870301  0.666197  0.117654  0.649658  0.916894  0.224512
# K  0.700279  0.126812  0.859340  0.635009  0.023160  0.835224  0.453145
# L  0.781124  0.668803  0.471647  0.749074  0.910765  0.345139  0.088982
# ...

# %%
df.describe()
# Out:
#                 A           B           C           D           E           F  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     0.464147    0.528746    0.477754    0.525200    0.514623    0.537962
# std      0.274324    0.292559    0.277837    0.282458    0.298504    0.282879
# min      0.003826    0.000086    0.019430    0.000979    0.000617    0.003550
# 25%      0.234159    0.291788    0.254897    0.298824    0.263239    0.319965
# 50%      0.455083    0.526033    0.479042    0.535046    0.528995    0.534372
# 75%      0.662573    0.801060    0.708096    0.761269    0.774889    0.774148
# max      0.995863    0.992342    0.989739    0.999114    0.998651    0.996237
#
#                 G           H           I           J  ...           P  \
# count  200.000000  200.000000  200.000000  200.000000  ...  200.000000
# mean     0.479258    0.451434    0.505454    0.512398  ...    0.440688
# ...

# %% [markdown]
# # 23- Reshaping a dataframe

# %%
fasla = pd.DataFrame([['12345', 100, 200], ['34567',400, 500],['67890',700, 800]], columns=['id', 'a', 'b', ])
fasla.head()
# Out:
#       id    a    b
# 0  12345  100  200
# 1  34567  400  500
# 2  67890  700  800

# %%
# fasla_melted = fasla.melt(id_vars='id', var_name='a', value_name='b')
# fasla_melted

# %%
sns.barplot(x='id',y='a',data=fasla)
# Out:
# <Axes: xlabel='id', ylabel='a'>
