# %%
import pandas as pd
import numpy as np 
import matplotlib as  plt 
import plotly as px 
import seaborn as sns

# %%
# plotting
sns.set_theme(style="whitegrid") 

diamonds = sns.load_dataset("diamonds")
clarity_range = ["I1","S12","SI1","VS1","VS1","VVS2","VVS1","IF"]
sns.boxenplot(x="clarity", y="carat",
              color="b", order="clarity_ranking",
              scale="linear",data=diamonds)
# Out:
# C:\Users\TECH ZONE\AppData\Local\Temp\ipykernel_11412\4008777272.py:6: FutureWarning:
#
# The `scale` parameter has been renamed to `width_method` and will be removed in v0.15. Pass `width_method='linear' for the same effect.
#   sns.boxenplot(x="clarity", y="carat",
# <Axes: xlabel='clarity', ylabel='carat'>
