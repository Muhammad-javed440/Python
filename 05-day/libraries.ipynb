# %% [markdown]
# 1. pandas  - to use excel  file
# 2. numpy  -  to use numpy array and  perform mathematical operations
# 3. matplotlib -  to plot the graph
# 4. seaborn - base on matplotlib
# 5. plotly - interactive  graph and to draw 3d plot
# 6. scipy.stats -  to use statistical functions
#
# 7. scikit-learn -to use machine learning
# 8. streamlit -  to create web app

# %%
# pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.8 MB 816.5 kB/s eta 0:00:09
#    ---- ----------------------------------- 0.8/7.8 MB 976.8 kB/s eta 0:00:08
#    ----- ---------------------------------- 1.0/7.8 MB 1.1 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.0/7.8 MB 1.1 MB/s eta 0:00:07
#    ------ --------------------------------- 1.3/7.8 MB 984.3 kB/s eta 0:00:07
#    --------- ------------------------------ 1.8/7.8 MB 1.1 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.1/7.8 MB 1.2 MB/s eta 0:00:05
#    ------------ --------------------------- 2.4/7.8 MB 1.2 MB/s eta 0:00:05
#    -------------- ------------------------- 2.9/7.8 MB 1.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.1/7.8 MB 1.3 MB/s eta 0:00:04
# ...

# %%
# pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/19.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/19.1 MB 1.8 MB/s eta 0:00:11
#    - -------------------------------------- 0.8/19.1 MB 1.8 MB/s eta 0:00:11
#    --- ------------------------------------ 1.6/19.1 MB 2.3 MB/s eta 0:00:08
#    ---- ----------------------------------- 2.1/19.1 MB 2.5 MB/s eta 0:00:07
#    ----- ---------------------------------- 2.6/19.1 MB 2.5 MB/s eta 0:00:07
#    ------ --------------------------------- 3.1/19.1 MB 2.5 MB/s eta 0:00:07
#    ------- -------------------------------- 3.7/19.1 MB 2.5 MB/s eta 0:00:07
#    -------- ------------------------------- 4.2/19.1 MB 2.4 MB/s eta 0:00:07
#    --------- ------------------------------ 4.5/19.1 MB 2.4 MB/s eta 0:00:07
# ...

# %%
# pip install scipy
# Out:
# ...
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.5/44.5 MB 1.1 MB/s eta 0:00:41
#     --------------------------------------- 0.8/44.5 MB 1.2 MB/s eta 0:00:38
#     --------------------------------------- 1.0/44.5 MB 1.1 MB/s eta 0:00:39
#    - -------------------------------------- 1.3/44.5 MB 1.2 MB/s eta 0:00:37
#    - -------------------------------------- 1.6/44.5 MB 1.2 MB/s eta 0:00:35
#    - -------------------------------------- 1.8/44.5 MB 1.3 MB/s eta 0:00:33
#    -- ------------------------------------- 2.4/44.5 MB 1.4 MB/s eta 0:00:31
#    -- ------------------------------------- 2.9/44.5 MB 1.5 MB/s eta 0:00:29
#    -- ------------------------------------- 3.1/44.5 MB 1.5 MB/s eta 0:00:28
# ...

# %%
# pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 1.8 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/11.0 MB 2.5 MB/s eta 0:00:04
#    ------- -------------------------------- 2.1/11.0 MB 3.1 MB/s eta 0:00:03
#    --------- ------------------------------ 2.6/11.0 MB 3.0 MB/s eta 0:00:03
#    ------------ --------------------------- 3.4/11.0 MB 3.1 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/11.0 MB 3.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.7/11.0 MB 3.2 MB/s eta 0:00:02
#    ------------------ --------------------- 5.0/11.0 MB 3.2 MB/s eta 0:00:02
#    ------------------ --------------------- 5.0/11.0 MB 3.2 MB/s eta 0:00:02
# ...

# %%
# pip install streamlit
# Out:
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.7 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/8.7 MB 2.3 MB/s eta 0:00:04
#    ------- -------------------------------- 1.6/8.7 MB 2.6 MB/s eta 0:00:03
#    --------- ------------------------------ 2.1/8.7 MB 2.6 MB/s eta 0:00:03
#    ------------- -------------------------- 2.9/8.7 MB 2.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.7/8.7 MB 2.9 MB/s eta 0:00:02
#    ------------------- -------------------- 4.2/8.7 MB 2.9 MB/s eta 0:00:02
#    --------------------- ------------------ 4.7/8.7 MB 2.8 MB/s eta 0:00:02
#    ------------------------- -------------- 5.5/8.7 MB 2.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.3/8.7 MB 2.9 MB/s eta 0:00:01
# ...
